# %%
# URL = 'http://localhost:3000'
URL = 'https://e-catalogue.abcdavid.top'

# %%
import requests
from requests_toolbelt.multipart.encoder import MultipartEncoder

# %%
def FileExists(filename):
    try:
        with open(filename, 'r') as f:
            return True
    except FileNotFoundError:
        return False

# %%
import enum

class RequestType(enum.Enum):
    GET = 0
    POST = 1
    PUT = 2
    DELETE = 3
    
class RequestBuilder:
    def __init__(self, url):
        self.url = url
        self.headers = {'Accept': 'application/json'}
        self.query = {}
        self.fields = {}
        self.token = None
        self.isMultipart = False
    
    def SetToken(self, token):
        self.token = token
        return self
        
    def AddHeader(self, key, value):
        self.headers[key] = str(value)
        return self
    
    def AddBody(self, key, value):
        self.fields[key] = str(value)
        return self
        
    def AddQuery(self, key, value):
        self.query[key] = str(value)
        return self
    
    def GetFile(self, path):
        if not FileExists(path):
            raise FileNotFoundError(path)
        
        filename = path.split('/')[-1]
        
        filetype = filename.split('.')[-1].lower()
        mimetype = None
        if filetype == 'jpg' or filetype == 'jpeg':
            mimetype = 'image/jpeg'
            
        if filetype == 'png':
            mimetype = 'image/png'
        
        if not mimetype:
            raise Exception('Unsupported file type')
        
        return (filename, open(path, 'rb'), mimetype)
    
    def AddFile(self, fieldname, path):
        # self.files.append((fieldname, self.GetFile(path)))
        self.fields[fieldname] = self.GetFile(path)
        self.isMultipart = True
        return self
        
    def Build(self, request_type):
        new_headers = self.headers.copy()
        if (self.token):
            new_headers['Authorization'] = 'Bearer ' + self.token
 
        if self.isMultipart and request_type in [RequestType.POST, RequestType.PUT]:
            encoder = MultipartEncoder(fields=self.fields)
            new_headers['Content-Type'] = encoder.content_type
            if request_type == RequestType.POST:
                return requests.post(self.url, headers=new_headers, params=self.query, data=encoder)
            elif request_type == RequestType.PUT:
                return requests.put(self.url, headers=new_headers, params=self.query, data=encoder)
            
        if request_type == RequestType.GET:
            return requests.get(self.url, headers=new_headers, params=self.query)
        elif request_type == RequestType.POST:
            return requests.post(self.url, headers=new_headers, params=self.query, data=self.fields)
        elif request_type == RequestType.PUT:
            return requests.put(self.url, headers=new_headers, params=self.query, data=self.fields)
        elif request_type == RequestType.DELETE:
            return requests.delete(self.url, headers=new_headers, params=self.query)
        raise Exception('Unsupported request type')
    
    def GET(self):
        return self.Build(RequestType.GET)
    
    def POST(self):
        return self.Build(RequestType.POST)
    
    def PUT(self):
        return self.Build(RequestType.PUT)
    
    def DELETE(self):
        return self.Build(RequestType.DELETE)

# %%
def login(username, password):

    res = (RequestBuilder(URL+'/auth/login')
           .AddBody('username', username)
           .AddBody('password', password)
           .POST())
    token = None
    if (res.status_code in [200, 201]):
        print(f'{username} login success')
        token = res.json()['access_token']
    else:
        print(f'{username} login failed')
        if (res.json()['message'] == 'User not found'):
            # raise Exception('User not found')
            return None
        else:
            print(res.json())
            exit(1)
    return token

# %%
class TokenManager:
    __STORE_TOKEN = None
    __STORE_USERNAME = 'spino'
    __STORE_PASSWORD = '123456'
    __STORE_ID = None
    
    @staticmethod
    def __init_store():
        TokenManager.__STORE_TOKEN = login(TokenManager.__STORE_USERNAME, TokenManager.__STORE_PASSWORD)
        if not TokenManager.__STORE_TOKEN:
            CreateUserRequest = (RequestBuilder(URL+'/users/createuser')
                                .AddBody('username', TokenManager.__STORE_USERNAME)
                                .AddBody('password', TokenManager.__STORE_PASSWORD)
                                .AddBody('email', TokenManager.__STORE_USERNAME + '@gmail.com')
                                .POST())
            if (CreateUserRequest.status_code not in [200, 201]):
                print('Create account failed')
            TokenManager.__STORE_TOKEN = login(TokenManager.__STORE_USERNAME, TokenManager.__STORE_PASSWORD)
                
        RegisterStoreRequest = (RequestBuilder(URL+'/product/store')
                                .AddBody('name', 'Abcdavid Store')
                                .AddBody('description', 'Store of Abcdavid')
                                .AddBody('address', '0')
                                .AddFile('logo', './CategoryImages/Boy-Accessories.png')
                                .AddHeader('Content-Type', 'multipart/form-data; charset=utf-8')
                                .SetToken(TokenManager.__STORE_TOKEN)
                                .POST())
        if (RegisterStoreRequest.status_code not in [200, 201]):
            print('Register store failed')
            exit(1)
        TokenManager.__STORE_ID = RegisterStoreRequest.json()['id']
    
    @staticmethod
    def StoreId():
        if not TokenManager.__STORE_ID:
            TokenManager.__init_store()
        return TokenManager.__STORE_ID
    
    @staticmethod
    def StoreToken():
        if not TokenManager.__STORE_TOKEN:
            TokenManager.__init_store()
        return TokenManager.__STORE_TOKEN

# %%
def calc_indent(numb: int) -> str:
    if numb < 2:
        return ""
    binary = bin(numb)[3:]
    ret = map(lambda x: "│  " if x == "1" else "   ", binary[:-1])
    return "".join(ret) + ( "└──" if binary[-1] == "0" else "├──")

class Category:
    def __init__(self, name, description, image):
        self.id = None
        self.name = name
        self.description = description if description else None
        self.children = []
        self.image = image
        self.same_name = True
        self.same_description = True
        
    def from_json(json):
        cat = Category(json['name'], json['description'], json['image'])
        cat.id = json['id']
        for child in json['children']:
            cat.children.append(Category.from_json(child))
        return cat
        
    def add_child(self, child):
        self.children.append(child)
    
    def add_child(self, name, description, image):
        self.children.append(Category(name, description, image))
        
    def add_children(self, children):
        self.children.extend(map(lambda x: 
            Category(x[0],x[1],x[2])
            if isinstance(x, tuple) 
            else Category(x, None, None)
            , children))
        
    def image_exists(self):
        if self.image:
            return FileExists('./CategoryImages/' + self.image)
        return False
        
    def __str__(self, indent=1):
        ret = calc_indent(indent) + self.__repr__() + "\n"
        for child in self.children[:-1]:
            ret += child.__str__(indent*2+1)
        if len(self.children) > 0:
            ret += self.children[-1].__str__(indent*2)
        return ret
    
    def __eq__(self, __value: object) -> bool:
        if isinstance(__value, Category):
            return self.name == __value.name
        else:
            return False
        
    def match(self, target: object):
        if not self == target:
            return
        self.id = target.id
        if not self.description and target.description:
            self.description = target.description
        if self.name != target.name:
            self.same_name = False
        if self.description != target.description:
            self.same_description = False
        for child in self.children:
            for target_child in target.children:
                if child == target_child:
                    child.match(target_child)
        
    def short_desc(self):
        if self.description:
            return self.description[:20] + "..." if len(self.description) > 20 else self.description
        else:
            return ""
    
    def __repr__(self):
        return f'[{self.id if self.id else "?"}] {"!" if not self.same_name else ""}{self.name} - {"!" if not self.same_description else ""}"{self.short_desc()}" {"!" if not self.image_exists() else ""}[{self.image if self.image else "None"}]'

    def get_child(self, name):
        for child in self.children:
            if child.name == name:
                return child
        return None

    def get_name_by_id(self, id):
        if self.id == id:
            return self.name
        for child in self.children:
            name = child.get_name_by_id(id)
            if name:
                return self.name + '/' + name
        return None

    def __getitem__(self, key):
        if hasattr(self, 'children') and isinstance(self.children, (list, dict)):
            return self.get_child(key)
        else:
            raise AttributeError("The 'children' attribute does not exist or is not subscriptable.")

# %%
class ServerCategory:
    
    __categories = {}
    __fetch = False
    
    @staticmethod
    def get_categories(cls):
        res = (RequestBuilder(URL+'/product/category/all')
               .GET())
        if res.status_code != 200:
            print(res).json()
            exit()
        for cat in res.json():
            cls.__categories[cat['name']] = Category.from_json(cat)
        return cls.__categories
    
    @staticmethod
    def __get_categories(cls):
        if not cls.__fetch:
            cls.__categories = cls.get_categories(cls)
            # cls.__fetch = True
        return cls.__categories
    
    @staticmethod
    def all():
        cats = []
        for cat in ServerCategory.__get_categories(ServerCategory).values():
            cats.append(cat)
        return cats
    
    def __class_getitem__(cls, key):
        return cls.__get_categories(cls).get(key)

# %%
print(ServerCategory.all())
print(ServerCategory['Men'])
# Out:
# [[1] Men - "" ![None], [30] Women - "" ![None], [64] Boy - "" ![None], [81] Girl - "" ![None]]
# [1] Men - "" ![None]
# ├──[2] Clothing - "" ![c3be579b-a8d2-11ee-94f9-c239f7a625f9.png]
# │  ├──[3] Coats - "" ![None]
# │  ├──[4] Cardigans and sweaters - "" ![None]
# │  ├──[5] Jackets and overshirts - "" ![None]
# │  ├──[6] Trousers - "" ![None]
# │  ├──[7] Shirts - "" ![None]
# │  ├──[8] Jeans - "" ![None]
# │  ├──[9] T-Shirts - "" ![None]
# │  ├──[10] Polos - "" ![None]
# │  ├──[11] Blazers - "" ![None]
# │  └──[12] Underwear - "" ![None]
# ├──[13] Suits - "" ![c4122a4c-a8d2-11ee-94f9-c239f7a625f9.png]
# │  ├──[14] Suits - "" ![None]
# │  ├──[15] Blazers - "" ![None]
# │  ├──[16] Trousers - "" ![None]
# │  ├──[17] Waistcoats - "" ![None]
# │  ├──[18] Shirts - "" ![None]
# │  └──[19] Accessories - "" ![None]
# └──[20] Shoes and accessories - "" ![c462e935-a8d2-11ee-94f9-c239f7a625f9.png]
#    ├──[21] Shoes - "" ![None]
#    ├──[22] Backpacks and bags - "" ![None]
#    ├──[23] Belts and braces - "" ![None]
#    ├──[24] Scarvers, caps and glovers - "" ![None]
#    ├──[25] Wallers - "" ![None]
#    ├──[26] Sunglasses - "" ![None]
#    ├──[27] Ties and bow ties - "" ![None]
#    ├──[28] Tailoring Accessories - "" ![None]
#    └──[29] Perfumes - "" ![None]

# %%
print(ServerCategory['Women'])
# Out:
# [30] Women - "" ![None]
# ├──[31] Clothing - "" ![cc40db55-a8d2-11ee-94f9-c239f7a625f9.png]
# │  ├──[32] Coats - "" ![None]
# │  ├──[33] Dresses and jumpsuits - "" ![None]
# │  ├──[34] Jackets and Suit Jackets - "" ![None]
# │  ├──[35] Sweaters and cardigans - "" ![None]
# │  ├──[36] Shirts - "" ![None]
# │  ├──[37] Leather - "" ![None]
# │  ├──[38] T-Shirts and tops - "" ![None]
# │  ├──[39] Sweatshirts - "" ![None]
# │  ├──[40] Trousers - "" ![None]
# │  ├──[41] Skirts - "" ![None]
# │  ├──[42] Jeans - "" ![None]
# │  └──[43] Pikinis and swimsuits - "" ![None]
# ├──[44] Shoes and Accessories - "" ![ce8be591-a8d2-11ee-94f9-c239f7a625f9.png]
# │  ├──[45] Shoes - "" ![None]
# │  ├──[46] Bags - "" ![None]
# │  ├──[47] Jewellery - "" ![None]
# │  ├──[48] Wallets and cases - "" ![None]
# │  ├──[49] Belts - "" ![None]
# │  ├──[50] Sunglasses - "" ![None]
# │  ├──[51] Scarvers and foulards - "" ![None]
# │  ├──[52] Caps and glovers - "" ![None]
# │  └──[53] Fragrances - "" ![None]
# └──[54] Plus Sizes - "" ![d077fdf9-a8d2-11ee-94f9-c239f7a625f9.png]
#    ├──[55] Coats - "" ![None]
#    ├──[56] Dresses and jumpsuits - "" ![None]
#    ├──[57] Jackets and Suit Jackets - "" ![None]
#    ├──[58] Sweaters and cardigans - "" ![None]
#    ├──[59] Shirts - "" ![None]
#    ├──[60] T-Shirts and tops - "" ![None]
#    ├──[61] Trousers - "" ![None]
#    ├──[62] Skirts - "" ![None]
#    └──[63] Jeans - "" ![None]

# %% [markdown]
# Add Product

# %%
def findCategoryIdByName(name):
    names = name.split('/')
    try:
        if len(names) == 1:
            return ServerCategory[names[0]].id
        elif len(names) == 2:
            return ServerCategory[names[0]][names[1]].id
        elif len(names) == 3:
            return ServerCategory[names[0]][names[1]][names[2]].id
        else:
            raise Exception("Invalid category name")
    except AttributeError as e:
        if "'NoneType' object has no attribute 'id'" in e.args:
            return None
        else:
            raise e

def getCategoryNameById(id):
    for cat in ServerCategory.all():
        name = cat.get_name_by_id(id)
        if name:
            return name
    return None

class ProductVariant:
    def __init__(self, product, color, size, price, quantity, image):
        self.id = None
        self.color = color
        self.size = size
        self.price = price
        self.quantity = quantity
        self.image = image
    
    def __repr__(self):
        return f'{self.color} - {self.size} - {self.price} - {self.quantity} - {self.image}'
    
    def image_exists(self):
        if self.image:
            return FileExists('./ProductImages/' + self.image)
        return False
    
    def update(self, productId: int):
        print(f'Updating variant {self} with product id {productId}')
        request = RequestBuilder(URL+'/product/variant').SetToken(TokenManager.StoreToken())

        request.AddQuery('product', str(productId))
        if self.color:
            request.AddQuery('color', self.color)
        if self.size:
            request.AddQuery('size', self.size)
        if self.price:
            request.AddBody('price', str(self.price))
        if self.quantity:
            request.AddBody('quantity', self.quantity)
        if self.image:
            request.AddFile('image', './ProductImages/' + self.image)
        res = request.POST()
        if res.status_code not in [200, 201]:
            print(f'Update product variant failed [{self.product}]')
            print(res.json())
            # raise Exception(f'[{res.status_code}] Failed to update product variant {self.product}')
        self.id = res.json()['id']
        print (f'[{self.id}] Updated product[{productId}] - {self.color} - {self.size} - {self.price} - {self.quantity}')        

class Product:
    def __init__(self, name, description, category, image):
        self.name = name
        self.description = description
        self.same_description = False
        self.category = category
        self.image = image
        self.variant = []
        
        self.id = None
        cat = findCategoryIdByName(self.category)
        if cat:
            self.category_id = cat
        else:
            raise Exception(f'Category {self.category} not found')
        # self.fetch()
        
    @staticmethod
    def all():
        return (RequestBuilder(URL+'/product/store')
                .AddQuery('id', TokenManager.StoreId())
                .GET()).json()['products']
        
    def fetch(self):
        products = Product.all()
        product = next((product for product in products if product['name'] == self.name and product['category']['id'] == self.category_id), None)
        if product:
            self.id = product['id']
            self.same_description = self.description == product['description']
    
    def add_variant(self, color, size, price, quantity, image):
        self.variant.append(ProductVariant(self.id, color, size, price, quantity, image))
        
    def add_variant_without_image(self, color, size, price, quantity):
        self.variant.append(ProductVariant(self.id, color, size, price, quantity, self.image))
    
    def __repr__(self):
        return f'[{self.id if self.id else "?"}] {"!" if not self.same_description else ""}{self.name} - "{self.description}" {"!" if not self.image_exists() else ""}[{self.image if self.image else "None"}]'
    
    def __str__(self) -> str:
        ret = self.__repr__() + "\n"
        for variant in self.variant[:-1]:
            ret += "├──" + variant.__repr__() + "\n"
        if len(self.variant) > 0:
            ret += "└──" + self.variant[-1].__repr__()
        return ret
    
    def image_exists(self):
        if self.image:
            return FileExists('./ProductImages/' + self.image)
        return False
    
    def update(self):
        if not self.id:
            self.__add()
        else:
            request = RequestBuilder(URL+'/product').SetToken(TokenManager.StoreToken()).AddQuery('id', self.id)
            if self.name:
                request.AddBody('name', self.name)
            if self.description:
                request.AddBody('description', self.description)
            if self.category_id:
                request.AddBody('category', self.category_id)
            if self.image:
                request.AddFile('image', './ProductImages/' + self.image)
            res = request.PUT()
            if res.status_code not in [200, 201]:
                print(f'Update product failed [{self.name}]')
                print(res.json())
                # raise Exception(f'[{res.status_code}] Failed to update product {self.name}')
            print (f'[{res.status_code}] Updated {self.name} - "{self.description}"')

        for variant in self.variant:
            print(f'Updating variant {variant} with product id {self.id}')
            variant.update(self.id)
            
    def __add(self):
        if self.id:
            print(f'Product {self.name} already exists')
            return
        if not self.name:
            raise Exception('Product name is required') 
        if not self.category_id:
            raise Exception('Product category is required')
        if not self.image or not self.image_exists():
            raise Exception('Product image is required')
        request = (RequestBuilder(URL+'/product/')
                   .SetToken(TokenManager.StoreToken())
                   .AddBody('name', self.name)
                   .AddBody('description', self.description)
                   .AddBody('category', self.category_id)
                   .AddFile('image', './ProductImages/' + self.image)
                   .POST())
        if request.status_code not in [200, 201]:
            print(f'Add product failed [{self.name}]')
            print(request.json())
            # raise Exception(f'[{request.status_code}] Failed to add product {self.name}')
        self.id = request.json()['id']
        print('Added product ' + self.name + ' with id ' + str(self.id))
    
    
    @staticmethod
    def from_json(json):
        return Product(json['name'], json['description'], json['category'], json['image'])

# %%
getCategoryNameById(28)
# Out:
# 'Men/Shoes and accessories/Tailoring Accessories'

# %%
findCategoryIdByName('Men/Shoes and accessories/Shoes')
# Out:
# 21

# %%
import pandas as pd
import os

data_folder = "./Data/Product/"  # replace with your actual folder path
files = os.listdir(data_folder)

dfs = []
for file in files:
    if file.endswith('.csv'):
        product_dataframe = pd.read_csv(os.path.join(data_folder, file))
        dfs.append(product_dataframe)

pdf = pd.concat(dfs, ignore_index=True).sort_values('id', ascending=True)

# %%
from enum import Enum

class Color(Enum):
    WHITES = 'Whites'
    BLACKS = 'Blacks'
    GREYS = 'Greys'
    BEIGES = 'Beiges'
    BROWNS = 'Browns'
    REDS = 'Reds'
    GREENS = 'Greens'
    BLUES = 'Blues'
    PURPLES = 'Purples'
    YELLOWS = 'Yellows'
    PINKS = 'Pinks'
    ORANGES = 'Oranges'
    
similar_color = {
    Color.WHITES.value: ['Silver'],
    Color.BLUES.value: ['Navy'],
    Color.BEIGES.value: ['Khaki', 'Nude', 'Ecru', 'Sand'],
    Color.BROWNS.value: ['Caramel', 'Chocolate', 'Coffee'],
    Color.REDS.value: ['Maroon', 'Burgundy'],
    Color.YELLOWS.value: ['Curry'],
    Color.PURPLES.value: ['Plum'],
    Color.PINKS.value: ['Fuchsia']
}


def parseColor(color_name: str) -> Color:
    for color in Color:
        if color.value[:-1].lower() in color_name.lower():
            return color
        if not similar_color.get(color.value):
            continue
        if len(similar_color[color.value]) <= 0:
            continue
        for sc in similar_color[color.value]:
            if sc.lower() in color_name.lower():
                return color
    return None
   
def canParseColor(color_name: str) -> bool:
    return parseColor(color_name) is not None

colors = pdf[pdf['name'].apply(lambda x: not canParseColor(x))]['name'].unique()
colors
# Out:
# array([], dtype=object)

# %%
class Size(Enum):
    XS = 'XS'
    S = 'S'
    M = 'M'
    L = 'L'
    XL = 'XL'
    XXL = 'XXL'

def variate_price(price: int, size: Size) -> int:
    price_fraction = round(price * 5 / 100, -2)
    if size == Size.XS:
        return price - price_fraction * 3
    if size == Size.S:
        return price - price_fraction * 2
    if size == Size.M:
        return price - price_fraction
    if size == Size.L:
        return price + price_fraction
    if size == Size.XL:
        return price + price_fraction * 2
    if size == Size.XXL:
        return price + price_fraction * 3

# %%
import pandas as pd
import os

data_folder = "./Data/Category/"  # replace with your actual folder path
files = os.listdir(data_folder)

dfs = []
for file in files:
    if file.endswith('.csv'):
        product_dataframe = pd.read_csv(os.path.join(data_folder, file))
        dfs.append(product_dataframe)

all_product_dataframe = pd.concat(dfs, ignore_index=True).sort_values('id', ascending=True)

# product_dataframe = pd.concat(dfs, ignore_index=True).sort_values('id', ascending=True)
product_dataframe = all_product_dataframe[all_product_dataframe['id'] % 2 == 0]

# %%
i = 0
for row in product_dataframe.values.tolist():
    i += 1
    if i > 5:
        break
    try:
        print('CategoryID:',findCategoryIdByName(row[2]))
    except Exception as e:
        print('CategoryID invalid:', row[2], '--'*50)
    print(row)
# Out:
# CategoryID: 3
# [2, 'Long recycled wool coat', 'Men/Clothing/Coats', 5499000]
# CategoryID: 3
# [4, 'Long recycled wool coat', 'Men/Clothing/Coats', 5499000]
# CategoryID: 3
# [6, 'Classic water-repellent trench coat', 'Men/Clothing/Coats', 4999000]
# CategoryID: 3
# [8, 'Reversible water-repellent quilted parka', 'Men/Clothing/Coats', 5999000]
# CategoryID: 3
# [10, 'Wool funnel neck coat', 'Men/Clothing/Coats', 5499000]

# %%
import random

product_data_folder = "./Data/Product/"

Products = []
for row in product_dataframe.values.tolist():
    path = os.path.join(product_data_folder, str(row[0]) + '.csv')
    pdf = pd.read_csv(path)
    product = Product(
        name=row[1],
        description=row[1],
        category=row[2],
        image=str(pdf['image_id'][0]) + '.png'
    )
    price = row[3]
    
    for variant in pdf.values.tolist():
        random_sizes = random.sample([Size.XS, Size.S, Size.M, Size.L, Size.XL, Size.XXL], random.randint(1, 6))
        for size in random_sizes:
            product.add_variant(
                color = parseColor(variant[1]).value,
                size = size.value,
                price = round(variate_price(price, size) / 23000),
                quantity = random.randint(100, 1000),
                image = str(variant[0]) + '.png'
            )
    Products.append(product)

# %%
for product in Products:
    print(product)
    product.update()
# Out:
# [?] !Long recycled wool coat - "Long recycled wool coat" [2.png]
# ├──Browns - L - 251 - 356 - 2.png
# ├──Browns - XS - 203 - 428 - 2.png
# ├──Browns - S - 215 - 115 - 2.png
# ├──Browns - M - 227 - 546 - 2.png
# ├──Blues - S - 215 - 160 - 3.png
# ├──Blues - XS - 203 - 919 - 3.png
# ├──Blues - M - 227 - 318 - 3.png
# ├──Blues - XL - 263 - 404 - 3.png
# ├──Blues - XXL - 275 - 979 - 3.png
# ├──Blacks - XL - 263 - 353 - 4.png
# ├──Greys - XS - 203 - 440 - 5.png
# ├──Greys - XXL - 275 - 171 - 5.png
# ├──Greys - L - 251 - 336 - 5.png
# ├──Greys - M - 227 - 696 - 5.png
# ├──Greys - XL - 263 - 139 - 5.png
# └──Greys - S - 215 - 223 - 5.png
# spino login success
# Added product Long recycled wool coat with id 188
# Updating variant Browns - L - 251 - 356 - 2.png with product id 188
# Updating variant Browns - L - 251 - 356 - 2.png with product id 188
# [806] Updated product[188] - Browns - L - 251 - 356
# Updating variant Browns - XS - 203 - 428 - 2.png with product id 188
# Updating variant Browns - XS - 203 - 428 - 2.png with product id 188
# [807] Updated product[188] - Browns - XS - 203 - 428
# Updating variant Browns - S - 215 - 115 - 2.png with product id 188
# Updating variant Browns - S - 215 - 115 - 2.png with product id 188
# [808] Updated product[188] - Browns - S - 215 - 115
# Updating variant Browns - M - 227 - 546 - 2.png with product id 188
# Updating variant Browns - M - 227 - 546 - 2.png with product id 188
# [809] Updated product[188] - Browns - M - 227 - 546
# Updating variant Blues - S - 215 - 160 - 3.png with product id 188
# Updating variant Blues - S - 215 - 160 - 3.png with product id 188
# [810] Updated product[188] - Blues - S - 215 - 160
# Updating variant Blues - XS - 203 - 919 - 3.png with product id 188
# Updating variant Blues - XS - 203 - 919 - 3.png with product id 188
# [811] Updated product[188] - Blues - XS - 203 - 919
# Updating variant Blues - M - 227 - 318 - 3.png with product id 188
# Updating variant Blues - M - 227 - 318 - 3.png with product id 188
# [812] Updated product[188] - Blues - M - 227 - 318
# Updating variant Blues - XL - 263 - 404 - 3.png with product id 188
# Updating variant Blues - XL - 263 - 404 - 3.png with product id 188
# [813] Updated product[188] - Blues - XL - 263 - 404
# Updating variant Blues - XXL - 275 - 979 - 3.png with product id 188
# Updating variant Blues - XXL - 275 - 979 - 3.png with product id 188
# [814] Updated product[188] - Blues - XXL - 275 - 979
# Updating variant Blacks - XL - 263 - 353 - 4.png with product id 188
# Updating variant Blacks - XL - 263 - 353 - 4.png with product id 188
# [815] Updated product[188] - Blacks - XL - 263 - 353
# Updating variant Greys - XS - 203 - 440 - 5.png with product id 188
# Updating variant Greys - XS - 203 - 440 - 5.png with product id 188
# [816] Updated product[188] - Greys - XS - 203 - 440
# Updating variant Greys - XXL - 275 - 171 - 5.png with product id 188
# Updating variant Greys - XXL - 275 - 171 - 5.png with product id 188
# [817] Updated product[188] - Greys - XXL - 275 - 171
# Updating variant Greys - L - 251 - 336 - 5.png with product id 188
# Updating variant Greys - L - 251 - 336 - 5.png with product id 188
# [818] Updated product[188] - Greys - L - 251 - 336
# Updating variant Greys - M - 227 - 696 - 5.png with product id 188
# Updating variant Greys - M - 227 - 696 - 5.png with product id 188
# [819] Updated product[188] - Greys - M - 227 - 696
# Updating variant Greys - XL - 263 - 139 - 5.png with product id 188
# Updating variant Greys - XL - 263 - 139 - 5.png with product id 188
# [820] Updated product[188] - Greys - XL - 263 - 139
# Updating variant Greys - S - 215 - 223 - 5.png with product id 188
# Updating variant Greys - S - 215 - 223 - 5.png with product id 188
# [821] Updated product[188] - Greys - S - 215 - 223
# [?] !Long recycled wool coat - "Long recycled wool coat" [8.png]
# ├──Greys - L - 251 - 990 - 8.png
# ├──Greys - XXL - 275 - 229 - 8.png
# ├──Greys - XS - 203 - 658 - 8.png
# ├──Greys - S - 215 - 221 - 8.png
# ├──Browns - M - 227 - 751 - 9.png
# ├──Browns - S - 215 - 575 - 9.png
# └──Browns - XS - 203 - 417 - 9.png
# Added product Long recycled wool coat with id 189
# Updating variant Greys - L - 251 - 990 - 8.png with product id 189
# Updating variant Greys - L - 251 - 990 - 8.png with product id 189
# [822] Updated product[189] - Greys - L - 251 - 990
# Updating variant Greys - XXL - 275 - 229 - 8.png with product id 189
# Updating variant Greys - XXL - 275 - 229 - 8.png with product id 189
# [823] Updated product[189] - Greys - XXL - 275 - 229
# Updating variant Greys - XS - 203 - 658 - 8.png with product id 189
# Updating variant Greys - XS - 203 - 658 - 8.png with product id 189
# [824] Updated product[189] - Greys - XS - 203 - 658
# Updating variant Greys - S - 215 - 221 - 8.png with product id 189
# Updating variant Greys - S - 215 - 221 - 8.png with product id 189
# [825] Updated product[189] - Greys - S - 215 - 221
# Updating variant Browns - M - 227 - 751 - 9.png with product id 189
# Updating variant Browns - M - 227 - 751 - 9.png with product id 189
# [826] Updated product[189] - Browns - M - 227 - 751
# Updating variant Browns - S - 215 - 575 - 9.png with product id 189
# Updating variant Browns - S - 215 - 575 - 9.png with product id 189
# [827] Updated product[189] - Browns - S - 215 - 575
# Updating variant Browns - XS - 203 - 417 - 9.png with product id 189
# Updating variant Browns - XS - 203 - 417 - 9.png with product id 189
# [828] Updated product[189] - Browns - XS - 203 - 417
# [?] !Classic water-repellent trench coat - "Classic water-repellent trench coat" [11.png]
# └──Browns - XXL - 250 - 566 - 11.png
# Added product Classic water-repellent trench coat with id 190
# Updating variant Browns - XXL - 250 - 566 - 11.png with product id 190
# Updating variant Browns - XXL - 250 - 566 - 11.png with product id 190
# [829] Updated product[190] - Browns - XXL - 250 - 566
# [?] !Reversible water-repellent quilted parka - "Reversible water-repellent quilted parka" [14.png]
# ├──Greys - S - 235 - 207 - 14.png
# ├──Greys - XS - 222 - 741 - 14.png
# ├──Greys - M - 248 - 530 - 14.png
# ├──Greys - XL - 287 - 566 - 14.png
# ├──Greys - L - 274 - 723 - 14.png
# └──Greys - XXL - 300 - 924 - 14.png
# Added product Reversible water-repellent quilted parka with id 191
# Updating variant Greys - S - 235 - 207 - 14.png with product id 191
# Updating variant Greys - S - 235 - 207 - 14.png with product id 191
# [830] Updated product[191] - Greys - S - 235 - 207
# Updating variant Greys - XS - 222 - 741 - 14.png with product id 191
# Updating variant Greys - XS - 222 - 741 - 14.png with product id 191
# [831] Updated product[191] - Greys - XS - 222 - 741
# Updating variant Greys - M - 248 - 530 - 14.png with product id 191
# Updating variant Greys - M - 248 - 530 - 14.png with product id 191
# [832] Updated product[191] - Greys - M - 248 - 530
# Updating variant Greys - XL - 287 - 566 - 14.png with product id 191
# Updating variant Greys - XL - 287 - 566 - 14.png with product id 191
# [833] Updated product[191] - Greys - XL - 287 - 566
# Updating variant Greys - L - 274 - 723 - 14.png with product id 191
# Updating variant Greys - L - 274 - 723 - 14.png with product id 191
# [834] Updated product[191] - Greys - L - 274 - 723
# Updating variant Greys - XXL - 300 - 924 - 14.png with product id 191
# Updating variant Greys - XXL - 300 - 924 - 14.png with product id 191
# [835] Updated product[191] - Greys - XXL - 300 - 924
# [?] !Wool funnel neck coat - "Wool funnel neck coat" [18.png]
# ├──Browns - XS - 203 - 980 - 18.png
# ├──Browns - S - 215 - 787 - 18.png
# ├──Blues - XL - 263 - 412 - 19.png
# ├──Blues - L - 251 - 338 - 19.png
# ├──Blues - M - 227 - 480 - 19.png
# ├──Blues - XXL - 275 - 675 - 19.png
# ├──Blues - S - 215 - 414 - 19.png
# ├──Blues - XS - 203 - 349 - 19.png
# ├──Blacks - XL - 263 - 678 - 20.png
# ├──Blacks - XXL - 275 - 837 - 20.png
# ├──Blacks - XS - 203 - 616 - 20.png
# ├──Greys - L - 251 - 512 - 21.png
# └──Greys - XL - 263 - 677 - 21.png
# Added product Wool funnel neck coat with id 192
# Updating variant Browns - XS - 203 - 980 - 18.png with product id 192
# Updating variant Browns - XS - 203 - 980 - 18.png with product id 192
# [836] Updated product[192] - Browns - XS - 203 - 980
# Updating variant Browns - S - 215 - 787 - 18.png with product id 192
# Updating variant Browns - S - 215 - 787 - 18.png with product id 192
# [837] Updated product[192] - Browns - S - 215 - 787
# Updating variant Blues - XL - 263 - 412 - 19.png with product id 192
# Updating variant Blues - XL - 263 - 412 - 19.png with product id 192
# [838] Updated product[192] - Blues - XL - 263 - 412
# Updating variant Blues - L - 251 - 338 - 19.png with product id 192
# Updating variant Blues - L - 251 - 338 - 19.png with product id 192
# [839] Updated product[192] - Blues - L - 251 - 338
# Updating variant Blues - M - 227 - 480 - 19.png with product id 192
# Updating variant Blues - M - 227 - 480 - 19.png with product id 192
# [840] Updated product[192] - Blues - M - 227 - 480
# Updating variant Blues - XXL - 275 - 675 - 19.png with product id 192
# Updating variant Blues - XXL - 275 - 675 - 19.png with product id 192
# [841] Updated product[192] - Blues - XXL - 275 - 675
# Updating variant Blues - S - 215 - 414 - 19.png with product id 192
# Updating variant Blues - S - 215 - 414 - 19.png with product id 192
# [842] Updated product[192] - Blues - S - 215 - 414
# Updating variant Blues - XS - 203 - 349 - 19.png with product id 192
# Updating variant Blues - XS - 203 - 349 - 19.png with product id 192
# [843] Updated product[192] - Blues - XS - 203 - 349
# Updating variant Blacks - XL - 263 - 678 - 20.png with product id 192
# Updating variant Blacks - XL - 263 - 678 - 20.png with product id 192
# [844] Updated product[192] - Blacks - XL - 263 - 678
# Updating variant Blacks - XXL - 275 - 837 - 20.png with product id 192
# Updating variant Blacks - XXL - 275 - 837 - 20.png with product id 192
# [845] Updated product[192] - Blacks - XXL - 275 - 837
# Updating variant Blacks - XS - 203 - 616 - 20.png with product id 192
# Updating variant Blacks - XS - 203 - 616 - 20.png with product id 192
# [846] Updated product[192] - Blacks - XS - 203 - 616
# Updating variant Greys - L - 251 - 512 - 21.png with product id 192
# Updating variant Greys - L - 251 - 512 - 21.png with product id 192
# [847] Updated product[192] - Greys - L - 251 - 512
# Updating variant Greys - XL - 263 - 677 - 21.png with product id 192
# Updating variant Greys - XL - 263 - 677 - 21.png with product id 192
# [848] Updated product[192] - Greys - XL - 263 - 677
# [?] !Recycled woollen coat - "Recycled woollen coat" [26.png]
# ├──Blacks - L - 251 - 739 - 26.png
# ├──Blacks - M - 227 - 746 - 26.png
# ├──Blacks - XL - 263 - 728 - 26.png
# ├──Browns - XL - 263 - 126 - 27.png
# ├──Browns - XS - 203 - 565 - 27.png
# ├──Browns - L - 251 - 555 - 27.png
# ├──Browns - XXL - 275 - 762 - 27.png
# ├──Blues - XL - 263 - 485 - 28.png
# ├──Blues - XS - 203 - 216 - 28.png
# └──Blues - L - 251 - 102 - 28.png
# Added product Recycled woollen coat with id 193
# Updating variant Blacks - L - 251 - 739 - 26.png with product id 193
# Updating variant Blacks - L - 251 - 739 - 26.png with product id 193
# [849] Updated product[193] - Blacks - L - 251 - 739
# Updating variant Blacks - M - 227 - 746 - 26.png with product id 193
# Updating variant Blacks - M - 227 - 746 - 26.png with product id 193
# [850] Updated product[193] - Blacks - M - 227 - 746
# Updating variant Blacks - XL - 263 - 728 - 26.png with product id 193
# Updating variant Blacks - XL - 263 - 728 - 26.png with product id 193
# [851] Updated product[193] - Blacks - XL - 263 - 728
# Updating variant Browns - XL - 263 - 126 - 27.png with product id 193
# Updating variant Browns - XL - 263 - 126 - 27.png with product id 193
# [852] Updated product[193] - Browns - XL - 263 - 126
# Updating variant Browns - XS - 203 - 565 - 27.png with product id 193
# Updating variant Browns - XS - 203 - 565 - 27.png with product id 193
# [853] Updated product[193] - Browns - XS - 203 - 565
# Updating variant Browns - L - 251 - 555 - 27.png with product id 193
# Updating variant Browns - L - 251 - 555 - 27.png with product id 193
# [854] Updated product[193] - Browns - L - 251 - 555
# Updating variant Browns - XXL - 275 - 762 - 27.png with product id 193
# Updating variant Browns - XXL - 275 - 762 - 27.png with product id 193
# [855] Updated product[193] - Browns - XXL - 275 - 762
# Updating variant Blues - XL - 263 - 485 - 28.png with product id 193
# Updating variant Blues - XL - 263 - 485 - 28.png with product id 193
# [856] Updated product[193] - Blues - XL - 263 - 485
# Updating variant Blues - XS - 203 - 216 - 28.png with product id 193
# Updating variant Blues - XS - 203 - 216 - 28.png with product id 193
# [857] Updated product[193] - Blues - XS - 203 - 216
# Updating variant Blues - L - 251 - 102 - 28.png with product id 193
# Updating variant Blues - L - 251 - 102 - 28.png with product id 193
# [858] Updated product[193] - Blues - L - 251 - 102
# [?] !Wool funnel neck coat - "Wool funnel neck coat" [30.png]
# ├──Greys - XXL - 275 - 248 - 30.png
# ├──Greys - XS - 203 - 227 - 30.png
# ├──Browns - XXL - 275 - 567 - 31.png
# ├──Browns - M - 227 - 160 - 31.png
# ├──Browns - XS - 203 - 321 - 31.png
# ├──Browns - XL - 263 - 565 - 31.png
# ├──Browns - S - 215 - 529 - 31.png
# └──Browns - L - 251 - 359 - 31.png
# Added product Wool funnel neck coat with id 194
# Updating variant Greys - XXL - 275 - 248 - 30.png with product id 194
# Updating variant Greys - XXL - 275 - 248 - 30.png with product id 194
# [859] Updated product[194] - Greys - XXL - 275 - 248
# Updating variant Greys - XS - 203 - 227 - 30.png with product id 194
# Updating variant Greys - XS - 203 - 227 - 30.png with product id 194
# [860] Updated product[194] - Greys - XS - 203 - 227
# Updating variant Browns - XXL - 275 - 567 - 31.png with product id 194
# Updating variant Browns - XXL - 275 - 567 - 31.png with product id 194
# [861] Updated product[194] - Browns - XXL - 275 - 567
# Updating variant Browns - M - 227 - 160 - 31.png with product id 194
# Updating variant Browns - M - 227 - 160 - 31.png with product id 194
# [862] Updated product[194] - Browns - M - 227 - 160
# Updating variant Browns - XS - 203 - 321 - 31.png with product id 194
# Updating variant Browns - XS - 203 - 321 - 31.png with product id 194
# [863] Updated product[194] - Browns - XS - 203 - 321
# Updating variant Browns - XL - 263 - 565 - 31.png with product id 194
# Updating variant Browns - XL - 263 - 565 - 31.png with product id 194
# [864] Updated product[194] - Browns - XL - 263 - 565
# Updating variant Browns - S - 215 - 529 - 31.png with product id 194
# Updating variant Browns - S - 215 - 529 - 31.png with product id 194
# [865] Updated product[194] - Browns - S - 215 - 529
# Updating variant Browns - L - 251 - 359 - 31.png with product id 194
# Updating variant Browns - L - 251 - 359 - 31.png with product id 194
# [866] Updated product[194] - Browns - L - 251 - 359
# [?] !Water-repellent quilted parka - "Water-repellent quilted parka" [36.png]
# ├──Blues - XS - 185 - 954 - 36.png
# ├──Blues - L - 228 - 628 - 36.png
# ├──Blues - S - 196 - 672 - 36.png
# ├──Blues - M - 206 - 569 - 36.png
# ├──Blues - XXL - 250 - 798 - 36.png
# └──Blues - XL - 239 - 793 - 36.png
# Added product Water-repellent quilted parka with id 195
# Updating variant Blues - XS - 185 - 954 - 36.png with product id 195
# Updating variant Blues - XS - 185 - 954 - 36.png with product id 195
# [867] Updated product[195] - Blues - XS - 185 - 954
# Updating variant Blues - L - 228 - 628 - 36.png with product id 195
# Updating variant Blues - L - 228 - 628 - 36.png with product id 195
# [868] Updated product[195] - Blues - L - 228 - 628
# Updating variant Blues - S - 196 - 672 - 36.png with product id 195
# Updating variant Blues - S - 196 - 672 - 36.png with product id 195
# [869] Updated product[195] - Blues - S - 196 - 672
# Updating variant Blues - M - 206 - 569 - 36.png with product id 195
# Updating variant Blues - M - 206 - 569 - 36.png with product id 195
# [870] Updated product[195] - Blues - M - 206 - 569
# Updating variant Blues - XXL - 250 - 798 - 36.png with product id 195
# Updating variant Blues - XXL - 250 - 798 - 36.png with product id 195
# [871] Updated product[195] - Blues - XXL - 250 - 798
# Updating variant Blues - XL - 239 - 793 - 36.png with product id 195
# Updating variant Blues - XL - 239 - 793 - 36.png with product id 195
# [872] Updated product[195] - Blues - XL - 239 - 793
# [?] !Quilted skin style jacket - "Quilted skin style jacket" [38.png]
# ├──Blacks - S - 156 - 724 - 38.png
# ├──Blacks - XS - 148 - 433 - 38.png
# ├──Blacks - XL - 191 - 187 - 38.png
# ├──Blacks - L - 183 - 185 - 38.png
# ├──Blacks - XXL - 200 - 656 - 38.png
# ├──Blacks - M - 165 - 992 - 38.png
# ├──Beiges - XXL - 200 - 552 - 39.png
# ├──Beiges - XL - 191 - 930 - 39.png
# ├──Beiges - L - 183 - 887 - 39.png
# ├──Beiges - M - 165 - 254 - 39.png
# ├──Beiges - S - 156 - 484 - 39.png
# └──Beiges - XS - 148 - 959 - 39.png
# Added product Quilted skin style jacket with id 196
# Updating variant Blacks - S - 156 - 724 - 38.png with product id 196
# Updating variant Blacks - S - 156 - 724 - 38.png with product id 196
# [873] Updated product[196] - Blacks - S - 156 - 724
# Updating variant Blacks - XS - 148 - 433 - 38.png with product id 196
# Updating variant Blacks - XS - 148 - 433 - 38.png with product id 196
# [874] Updated product[196] - Blacks - XS - 148 - 433
# Updating variant Blacks - XL - 191 - 187 - 38.png with product id 196
# Updating variant Blacks - XL - 191 - 187 - 38.png with product id 196
# [875] Updated product[196] - Blacks - XL - 191 - 187
# Updating variant Blacks - L - 183 - 185 - 38.png with product id 196
# Updating variant Blacks - L - 183 - 185 - 38.png with product id 196
# [876] Updated product[196] - Blacks - L - 183 - 185
# Updating variant Blacks - XXL - 200 - 656 - 38.png with product id 196
# Updating variant Blacks - XXL - 200 - 656 - 38.png with product id 196
# [877] Updated product[196] - Blacks - XXL - 200 - 656
# Updating variant Blacks - M - 165 - 992 - 38.png with product id 196
# Updating variant Blacks - M - 165 - 992 - 38.png with product id 196
# [878] Updated product[196] - Blacks - M - 165 - 992
# Updating variant Beiges - XXL - 200 - 552 - 39.png with product id 196
# Updating variant Beiges - XXL - 200 - 552 - 39.png with product id 196
# [879] Updated product[196] - Beiges - XXL - 200 - 552
# Updating variant Beiges - XL - 191 - 930 - 39.png with product id 196
# Updating variant Beiges - XL - 191 - 930 - 39.png with product id 196
# [880] Updated product[196] - Beiges - XL - 191 - 930
# Updating variant Beiges - L - 183 - 887 - 39.png with product id 196
# Updating variant Beiges - L - 183 - 887 - 39.png with product id 196
# [881] Updated product[196] - Beiges - L - 183 - 887
# Updating variant Beiges - M - 165 - 254 - 39.png with product id 196
# Updating variant Beiges - M - 165 - 254 - 39.png with product id 196
# [882] Updated product[196] - Beiges - M - 165 - 254
# Updating variant Beiges - S - 156 - 484 - 39.png with product id 196
# Updating variant Beiges - S - 156 - 484 - 39.png with product id 196
# [883] Updated product[196] - Beiges - S - 156 - 484
# Updating variant Beiges - XS - 148 - 959 - 39.png with product id 196
# Updating variant Beiges - XS - 148 - 959 - 39.png with product id 196
# [884] Updated product[196] - Beiges - XS - 148 - 959
# [?] !Turtleneck wool sweater - "Turtleneck wool sweater" [43.png]
# ├──Greys - M - 74 - 975 - 43.png
# ├──Greys - XL - 86 - 640 - 43.png
# ├──Greys - XXL - 90 - 798 - 43.png
# ├──Greys - L - 82 - 475 - 43.png
# └──Greys - S - 70 - 176 - 43.png
# Added product Turtleneck wool sweater with id 197
# Updating variant Greys - M - 74 - 975 - 43.png with product id 197
# Updating variant Greys - M - 74 - 975 - 43.png with product id 197
# [885] Updated product[197] - Greys - M - 74 - 975
# Updating variant Greys - XL - 86 - 640 - 43.png with product id 197
# Updating variant Greys - XL - 86 - 640 - 43.png with product id 197
# [886] Updated product[197] - Greys - XL - 86 - 640
# Updating variant Greys - XXL - 90 - 798 - 43.png with product id 197
# Updating variant Greys - XXL - 90 - 798 - 43.png with product id 197
# [887] Updated product[197] - Greys - XXL - 90 - 798
# Updating variant Greys - L - 82 - 475 - 43.png with product id 197
# Updating variant Greys - L - 82 - 475 - 43.png with product id 197
# [888] Updated product[197] - Greys - L - 82 - 475
# Updating variant Greys - S - 70 - 176 - 43.png with product id 197
# Updating variant Greys - S - 70 - 176 - 43.png with product id 197
# [889] Updated product[197] - Greys - S - 70 - 176
# [?] !Fine-knit polo shirt - "Fine-knit polo shirt" [45.png]
# ├──Greys - XXL - 45 - 136 - 45.png
# ├──Greys - S - 35 - 299 - 45.png
# └──Greys - XL - 43 - 991 - 45.png
# Added product Fine-knit polo shirt with id 198
# Updating variant Greys - XXL - 45 - 136 - 45.png with product id 198
# Updating variant Greys - XXL - 45 - 136 - 45.png with product id 198
# [890] Updated product[198] - Greys - XXL - 45 - 136
# Updating variant Greys - S - 35 - 299 - 45.png with product id 198
# Updating variant Greys - S - 35 - 299 - 45.png with product id 198
# [891] Updated product[198] - Greys - S - 35 - 299
# Updating variant Greys - XL - 43 - 991 - 45.png with product id 198
# Updating variant Greys - XL - 43 - 991 - 45.png with product id 198
# [892] Updated product[198] - Greys - XL - 43 - 991
# [?] !Fine-knit polo shirt - "Fine-knit polo shirt" [47.png]
# ├──Whites - S - 35 - 384 - 47.png
# ├──Whites - L - 41 - 309 - 47.png
# ├──Whites - XL - 43 - 899 - 47.png
# └──Whites - M - 37 - 141 - 47.png
# Added product Fine-knit polo shirt with id 199
# Updating variant Whites - S - 35 - 384 - 47.png with product id 199
# Updating variant Whites - S - 35 - 384 - 47.png with product id 199
# [893] Updated product[199] - Whites - S - 35 - 384
# Updating variant Whites - L - 41 - 309 - 47.png with product id 199
# Updating variant Whites - L - 41 - 309 - 47.png with product id 199
# [894] Updated product[199] - Whites - L - 41 - 309
# Updating variant Whites - XL - 43 - 899 - 47.png with product id 199
# Updating variant Whites - XL - 43 - 899 - 47.png with product id 199
# [895] Updated product[199] - Whites - XL - 43 - 899
# Updating variant Whites - M - 37 - 141 - 47.png with product id 199
# Updating variant Whites - M - 37 - 141 - 47.png with product id 199
# [896] Updated product[199] - Whites - M - 37 - 141
# [?] !Fine-knit polo shirt - "Fine-knit polo shirt" [49.png]
# ├──Oranges - XS - 33 - 302 - 49.png
# ├──Oranges - XXL - 45 - 563 - 49.png
# ├──Oranges - S - 35 - 465 - 49.png
# ├──Oranges - XL - 43 - 832 - 49.png
# └──Oranges - M - 37 - 607 - 49.png
# Added product Fine-knit polo shirt with id 200
# Updating variant Oranges - XS - 33 - 302 - 49.png with product id 200
# Updating variant Oranges - XS - 33 - 302 - 49.png with product id 200
# [897] Updated product[200] - Oranges - XS - 33 - 302
# Updating variant Oranges - XXL - 45 - 563 - 49.png with product id 200
# Updating variant Oranges - XXL - 45 - 563 - 49.png with product id 200
# [898] Updated product[200] - Oranges - XXL - 45 - 563
# Updating variant Oranges - S - 35 - 465 - 49.png with product id 200
# Updating variant Oranges - S - 35 - 465 - 49.png with product id 200
# [899] Updated product[200] - Oranges - S - 35 - 465
# Updating variant Oranges - XL - 43 - 832 - 49.png with product id 200
# Updating variant Oranges - XL - 43 - 832 - 49.png with product id 200
# [900] Updated product[200] - Oranges - XL - 43 - 832
# Updating variant Oranges - M - 37 - 607 - 49.png with product id 200
# Updating variant Oranges - M - 37 - 607 - 49.png with product id 200
# [901] Updated product[200] - Oranges - M - 37 - 607
# [?] !Fine-knit polo shirt - "Fine-knit polo shirt" [51.png]
# ├──Whites - L - 41 - 603 - 51.png
# ├──Whites - S - 35 - 786 - 51.png
# ├──Whites - XL - 43 - 962 - 51.png
# ├──Whites - XXL - 45 - 989 - 51.png
# ├──Whites - M - 37 - 682 - 51.png
# ├──Whites - XS - 33 - 100 - 51.png
# ├──Blacks - XXL - 45 - 436 - 52.png
# ├──Blacks - XL - 43 - 802 - 52.png
# ├──Blacks - L - 41 - 839 - 52.png
# ├──Blacks - XS - 33 - 888 - 52.png
# ├──Blacks - S - 35 - 204 - 52.png
# ├──Greys - M - 37 - 502 - 53.png
# ├──Greys - XL - 43 - 709 - 53.png
# ├──Greys - XXL - 45 - 981 - 53.png
# ├──Greys - L - 41 - 991 - 53.png
# ├──Greys - XS - 33 - 634 - 53.png
# ├──Greys - S - 35 - 753 - 53.png
# ├──Greens - M - 37 - 942 - 54.png
# ├──Greens - XS - 33 - 973 - 54.png
# ├──Greens - XXL - 45 - 219 - 54.png
# ├──Greens - L - 41 - 870 - 54.png
# ├──Yellows - XXL - 45 - 417 - 55.png
# └──Yellows - S - 35 - 922 - 55.png
# Added product Fine-knit polo shirt with id 201
# Updating variant Whites - L - 41 - 603 - 51.png with product id 201
# Updating variant Whites - L - 41 - 603 - 51.png with product id 201
# [902] Updated product[201] - Whites - L - 41 - 603
# Updating variant Whites - S - 35 - 786 - 51.png with product id 201
# Updating variant Whites - S - 35 - 786 - 51.png with product id 201
# [903] Updated product[201] - Whites - S - 35 - 786
# Updating variant Whites - XL - 43 - 962 - 51.png with product id 201
# Updating variant Whites - XL - 43 - 962 - 51.png with product id 201
# [904] Updated product[201] - Whites - XL - 43 - 962
# Updating variant Whites - XXL - 45 - 989 - 51.png with product id 201
# Updating variant Whites - XXL - 45 - 989 - 51.png with product id 201
# [905] Updated product[201] - Whites - XXL - 45 - 989
# Updating variant Whites - M - 37 - 682 - 51.png with product id 201
# Updating variant Whites - M - 37 - 682 - 51.png with product id 201
# [906] Updated product[201] - Whites - M - 37 - 682
# Updating variant Whites - XS - 33 - 100 - 51.png with product id 201
# Updating variant Whites - XS - 33 - 100 - 51.png with product id 201
# [907] Updated product[201] - Whites - XS - 33 - 100
# Updating variant Blacks - XXL - 45 - 436 - 52.png with product id 201
# Updating variant Blacks - XXL - 45 - 436 - 52.png with product id 201
# [908] Updated product[201] - Blacks - XXL - 45 - 436
# Updating variant Blacks - XL - 43 - 802 - 52.png with product id 201
# Updating variant Blacks - XL - 43 - 802 - 52.png with product id 201
# [909] Updated product[201] - Blacks - XL - 43 - 802
# Updating variant Blacks - L - 41 - 839 - 52.png with product id 201
# Updating variant Blacks - L - 41 - 839 - 52.png with product id 201
# [910] Updated product[201] - Blacks - L - 41 - 839
# Updating variant Blacks - XS - 33 - 888 - 52.png with product id 201
# Updating variant Blacks - XS - 33 - 888 - 52.png with product id 201
# [911] Updated product[201] - Blacks - XS - 33 - 888
# Updating variant Blacks - S - 35 - 204 - 52.png with product id 201
# Updating variant Blacks - S - 35 - 204 - 52.png with product id 201
# [912] Updated product[201] - Blacks - S - 35 - 204
# Updating variant Greys - M - 37 - 502 - 53.png with product id 201
# Updating variant Greys - M - 37 - 502 - 53.png with product id 201
# [913] Updated product[201] - Greys - M - 37 - 502
# Updating variant Greys - XL - 43 - 709 - 53.png with product id 201
# Updating variant Greys - XL - 43 - 709 - 53.png with product id 201
# [914] Updated product[201] - Greys - XL - 43 - 709
# Updating variant Greys - XXL - 45 - 981 - 53.png with product id 201
# Updating variant Greys - XXL - 45 - 981 - 53.png with product id 201
# [915] Updated product[201] - Greys - XXL - 45 - 981
# Updating variant Greys - L - 41 - 991 - 53.png with product id 201
# Updating variant Greys - L - 41 - 991 - 53.png with product id 201
# [916] Updated product[201] - Greys - L - 41 - 991
# Updating variant Greys - XS - 33 - 634 - 53.png with product id 201
# Updating variant Greys - XS - 33 - 634 - 53.png with product id 201
# [917] Updated product[201] - Greys - XS - 33 - 634
# Updating variant Greys - S - 35 - 753 - 53.png with product id 201
# Updating variant Greys - S - 35 - 753 - 53.png with product id 201
# [918] Updated product[201] - Greys - S - 35 - 753
# Updating variant Greens - M - 37 - 942 - 54.png with product id 201
# Updating variant Greens - M - 37 - 942 - 54.png with product id 201
# [919] Updated product[201] - Greens - M - 37 - 942
# Updating variant Greens - XS - 33 - 973 - 54.png with product id 201
# Updating variant Greens - XS - 33 - 973 - 54.png with product id 201
# [920] Updated product[201] - Greens - XS - 33 - 973
# Updating variant Greens - XXL - 45 - 219 - 54.png with product id 201
# Updating variant Greens - XXL - 45 - 219 - 54.png with product id 201
# [921] Updated product[201] - Greens - XXL - 45 - 219
# Updating variant Greens - L - 41 - 870 - 54.png with product id 201
# Updating variant Greens - L - 41 - 870 - 54.png with product id 201
# [922] Updated product[201] - Greens - L - 41 - 870
# Updating variant Yellows - XXL - 45 - 417 - 55.png with product id 201
# Updating variant Yellows - XXL - 45 - 417 - 55.png with product id 201
# [923] Updated product[201] - Yellows - XXL - 45 - 417
# Updating variant Yellows - S - 35 - 922 - 55.png with product id 201
# Updating variant Yellows - S - 35 - 922 - 55.png with product id 201
# [924] Updated product[201] - Yellows - S - 35 - 922
# [?] !Long-sleeved cotton jersey polo shirt - "Long-sleeved cotton jersey polo shirt" [57.png]
# ├──Greys - XXL - 45 - 491 - 57.png
# └──Greys - M - 37 - 600 - 57.png
# Added product Long-sleeved cotton jersey polo shirt with id 202
# Updating variant Greys - XXL - 45 - 491 - 57.png with product id 202
# Updating variant Greys - XXL - 45 - 491 - 57.png with product id 202
# [925] Updated product[202] - Greys - XXL - 45 - 491
# Updating variant Greys - M - 37 - 600 - 57.png with product id 202
# Updating variant Greys - M - 37 - 600 - 57.png with product id 202
# [926] Updated product[202] - Greys - M - 37 - 600
# [?] !Ribbed cotton polo shirt - "Ribbed cotton polo shirt" [59.png]
# ├──Browns - XXL - 45 - 644 - 59.png
# ├──Browns - XS - 33 - 995 - 59.png
# ├──Browns - S - 35 - 739 - 59.png
# └──Browns - XL - 43 - 693 - 59.png
# Added product Ribbed cotton polo shirt with id 203
# Updating variant Browns - XXL - 45 - 644 - 59.png with product id 203
# Updating variant Browns - XXL - 45 - 644 - 59.png with product id 203
# [927] Updated product[203] - Browns - XXL - 45 - 644
# Updating variant Browns - XS - 33 - 995 - 59.png with product id 203
# Updating variant Browns - XS - 33 - 995 - 59.png with product id 203
# [928] Updated product[203] - Browns - XS - 33 - 995
# Updating variant Browns - S - 35 - 739 - 59.png with product id 203
# Updating variant Browns - S - 35 - 739 - 59.png with product id 203
# [929] Updated product[203] - Browns - S - 35 - 739
# Updating variant Browns - XL - 43 - 693 - 59.png with product id 203
# Updating variant Browns - XL - 43 - 693 - 59.png with product id 203
# [930] Updated product[203] - Browns - XL - 43 - 693
# [?] !Fine-knit polo shirt - "Fine-knit polo shirt" [61.png]
# ├──Greens - XS - 33 - 242 - 61.png
# ├──Greens - M - 37 - 379 - 61.png
# ├──Greens - XL - 43 - 852 - 61.png
# ├──Blacks - XXL - 45 - 804 - 62.png
# ├──Greys - S - 35 - 545 - 63.png
# ├──Greys - M - 37 - 345 - 63.png
# ├──Greys - XL - 43 - 598 - 63.png
# ├──Greys - XS - 33 - 569 - 63.png
# ├──Greys - L - 41 - 666 - 63.png
# ├──Greys - XXL - 45 - 361 - 63.png
# ├──Greens - S - 35 - 275 - 64.png
# ├──Yellows - M - 37 - 831 - 65.png
# ├──Yellows - L - 41 - 552 - 65.png
# └──Yellows - XXL - 45 - 258 - 65.png
# Added product Fine-knit polo shirt with id 204
# Updating variant Greens - XS - 33 - 242 - 61.png with product id 204
# Updating variant Greens - XS - 33 - 242 - 61.png with product id 204
# [931] Updated product[204] - Greens - XS - 33 - 242
# Updating variant Greens - M - 37 - 379 - 61.png with product id 204
# Updating variant Greens - M - 37 - 379 - 61.png with product id 204
# [932] Updated product[204] - Greens - M - 37 - 379
# Updating variant Greens - XL - 43 - 852 - 61.png with product id 204
# Updating variant Greens - XL - 43 - 852 - 61.png with product id 204
# [933] Updated product[204] - Greens - XL - 43 - 852
# Updating variant Blacks - XXL - 45 - 804 - 62.png with product id 204
# Updating variant Blacks - XXL - 45 - 804 - 62.png with product id 204
# [934] Updated product[204] - Blacks - XXL - 45 - 804
# Updating variant Greys - S - 35 - 545 - 63.png with product id 204
# Updating variant Greys - S - 35 - 545 - 63.png with product id 204
# [935] Updated product[204] - Greys - S - 35 - 545
# Updating variant Greys - M - 37 - 345 - 63.png with product id 204
# Updating variant Greys - M - 37 - 345 - 63.png with product id 204
# [936] Updated product[204] - Greys - M - 37 - 345
# Updating variant Greys - XL - 43 - 598 - 63.png with product id 204
# Updating variant Greys - XL - 43 - 598 - 63.png with product id 204
# [937] Updated product[204] - Greys - XL - 43 - 598
# Updating variant Greys - XS - 33 - 569 - 63.png with product id 204
# Updating variant Greys - XS - 33 - 569 - 63.png with product id 204
# [938] Updated product[204] - Greys - XS - 33 - 569
# Updating variant Greys - L - 41 - 666 - 63.png with product id 204
# Updating variant Greys - L - 41 - 666 - 63.png with product id 204
# [939] Updated product[204] - Greys - L - 41 - 666
# Updating variant Greys - XXL - 45 - 361 - 63.png with product id 204
# Updating variant Greys - XXL - 45 - 361 - 63.png with product id 204
# [940] Updated product[204] - Greys - XXL - 45 - 361
# Updating variant Greens - S - 35 - 275 - 64.png with product id 204
# Updating variant Greens - S - 35 - 275 - 64.png with product id 204
# [941] Updated product[204] - Greens - S - 35 - 275
# Updating variant Yellows - M - 37 - 831 - 65.png with product id 204
# Updating variant Yellows - M - 37 - 831 - 65.png with product id 204
# [942] Updated product[204] - Yellows - M - 37 - 831
# Updating variant Yellows - L - 41 - 552 - 65.png with product id 204
# Updating variant Yellows - L - 41 - 552 - 65.png with product id 204
# [943] Updated product[204] - Yellows - L - 41 - 552
# Updating variant Yellows - XXL - 45 - 258 - 65.png with product id 204
# Updating variant Yellows - XXL - 45 - 258 - 65.png with product id 204
# [944] Updated product[204] - Yellows - XXL - 45 - 258
# [?] !Polo collar wool sweater - "Polo collar wool sweater" [67.png]
# ├──Beiges - XXL - 100 - 434 - 67.png
# ├──Beiges - L - 91 - 867 - 67.png
# ├──Beiges - S - 78 - 149 - 67.png
# ├──Beiges - XL - 96 - 395 - 67.png
# └──Beiges - XS - 74 - 470 - 67.png
# Added product Polo collar wool sweater with id 205
# Updating variant Beiges - XXL - 100 - 434 - 67.png with product id 205
# Updating variant Beiges - XXL - 100 - 434 - 67.png with product id 205
# [945] Updated product[205] - Beiges - XXL - 100 - 434
# Updating variant Beiges - L - 91 - 867 - 67.png with product id 205
# Updating variant Beiges - L - 91 - 867 - 67.png with product id 205
# [946] Updated product[205] - Beiges - L - 91 - 867
# Updating variant Beiges - S - 78 - 149 - 67.png with product id 205
# Updating variant Beiges - S - 78 - 149 - 67.png with product id 205
# [947] Updated product[205] - Beiges - S - 78 - 149
# Updating variant Beiges - XL - 96 - 395 - 67.png with product id 205
# Updating variant Beiges - XL - 96 - 395 - 67.png with product id 205
# [948] Updated product[205] - Beiges - XL - 96 - 395
# Updating variant Beiges - XS - 74 - 470 - 67.png with product id 205
# Updating variant Beiges - XS - 74 - 470 - 67.png with product id 205
# [949] Updated product[205] - Beiges - XS - 74 - 470
# [?] !Fine modal-silk sweater - "Fine modal-silk sweater" [69.png]
# ├──Greys - XL - 96 - 874 - 69.png
# ├──Greys - XXL - 100 - 238 - 69.png
# └──Greys - S - 78 - 813 - 69.png
# Added product Fine modal-silk sweater with id 206
# Updating variant Greys - XL - 96 - 874 - 69.png with product id 206
# Updating variant Greys - XL - 96 - 874 - 69.png with product id 206
# [950] Updated product[206] - Greys - XL - 96 - 874
# Updating variant Greys - XXL - 100 - 238 - 69.png with product id 206
# Updating variant Greys - XXL - 100 - 238 - 69.png with product id 206
# [951] Updated product[206] - Greys - XXL - 100 - 238
# Updating variant Greys - S - 78 - 813 - 69.png with product id 206
# Updating variant Greys - S - 78 - 813 - 69.png with product id 206
# [952] Updated product[206] - Greys - S - 78 - 813
# [?] !Recycled fabric slim-fit trousers - "Recycled fabric slim-fit trousers" [71.png]
# ├──Beiges - M - 58 - 887 - 71.png
# ├──Beiges - L - 64 - 140 - 71.png
# ├──Beiges - S - 55 - 714 - 71.png
# ├──Beiges - XL - 67 - 499 - 71.png
# ├──Beiges - XS - 52 - 326 - 71.png
# ├──Browns - S - 55 - 795 - 72.png
# ├──Browns - M - 58 - 269 - 72.png
# ├──Browns - L - 64 - 568 - 72.png
# ├──Browns - XS - 52 - 860 - 72.png
# ├──Browns - XL - 67 - 765 - 72.png
# ├──Greys - XS - 52 - 135 - 73.png
# ├──Greys - S - 55 - 228 - 73.png
# └──Greys - L - 64 - 124 - 73.png
# Added product Recycled fabric slim-fit trousers with id 207
# Updating variant Beiges - M - 58 - 887 - 71.png with product id 207
# Updating variant Beiges - M - 58 - 887 - 71.png with product id 207
# [953] Updated product[207] - Beiges - M - 58 - 887
# Updating variant Beiges - L - 64 - 140 - 71.png with product id 207
# Updating variant Beiges - L - 64 - 140 - 71.png with product id 207
# [954] Updated product[207] - Beiges - L - 64 - 140
# Updating variant Beiges - S - 55 - 714 - 71.png with product id 207
# Updating variant Beiges - S - 55 - 714 - 71.png with product id 207
# [955] Updated product[207] - Beiges - S - 55 - 714
# Updating variant Beiges - XL - 67 - 499 - 71.png with product id 207
# Updating variant Beiges - XL - 67 - 499 - 71.png with product id 207
# [956] Updated product[207] - Beiges - XL - 67 - 499
# Updating variant Beiges - XS - 52 - 326 - 71.png with product id 207
# Updating variant Beiges - XS - 52 - 326 - 71.png with product id 207
# [957] Updated product[207] - Beiges - XS - 52 - 326
# Updating variant Browns - S - 55 - 795 - 72.png with product id 207
# Updating variant Browns - S - 55 - 795 - 72.png with product id 207
# [958] Updated product[207] - Browns - S - 55 - 795
# Updating variant Browns - M - 58 - 269 - 72.png with product id 207
# Updating variant Browns - M - 58 - 269 - 72.png with product id 207
# [959] Updated product[207] - Browns - M - 58 - 269
# Updating variant Browns - L - 64 - 568 - 72.png with product id 207
# Updating variant Browns - L - 64 - 568 - 72.png with product id 207
# [960] Updated product[207] - Browns - L - 64 - 568
# Updating variant Browns - XS - 52 - 860 - 72.png with product id 207
# Updating variant Browns - XS - 52 - 860 - 72.png with product id 207
# [961] Updated product[207] - Browns - XS - 52 - 860
# Updating variant Browns - XL - 67 - 765 - 72.png with product id 207
# Updating variant Browns - XL - 67 - 765 - 72.png with product id 207
# [962] Updated product[207] - Browns - XL - 67 - 765
# Updating variant Greys - XS - 52 - 135 - 73.png with product id 207
# Updating variant Greys - XS - 52 - 135 - 73.png with product id 207
# [963] Updated product[207] - Greys - XS - 52 - 135
# Updating variant Greys - S - 55 - 228 - 73.png with product id 207
# Updating variant Greys - S - 55 - 228 - 73.png with product id 207
# [964] Updated product[207] - Greys - S - 55 - 228
# Updating variant Greys - L - 64 - 124 - 73.png with product id 207
# Updating variant Greys - L - 64 - 124 - 73.png with product id 207
# [965] Updated product[207] - Greys - L - 64 - 124
# [?] !Recycled fabric slim-fit trousers - "Recycled fabric slim-fit trousers" [78.png]
# ├──Blacks - L - 64 - 386 - 78.png
# ├──Blacks - XL - 67 - 902 - 78.png
# ├──Blacks - S - 55 - 804 - 78.png
# ├──Blacks - XXL - 70 - 658 - 78.png
# ├──Blacks - M - 58 - 895 - 78.png
# ├──Blacks - XS - 52 - 226 - 78.png
# ├──Browns - S - 55 - 246 - 79.png
# ├──Browns - L - 64 - 519 - 79.png
# ├──Browns - XL - 67 - 310 - 79.png
# ├──Browns - XS - 52 - 181 - 79.png
# ├──Greys - XXL - 70 - 669 - 80.png
# ├──Greys - XL - 67 - 275 - 80.png
# └──Greys - S - 55 - 979 - 80.png
# Added product Recycled fabric slim-fit trousers with id 208
# Updating variant Blacks - L - 64 - 386 - 78.png with product id 208
# Updating variant Blacks - L - 64 - 386 - 78.png with product id 208
# [966] Updated product[208] - Blacks - L - 64 - 386
# Updating variant Blacks - XL - 67 - 902 - 78.png with product id 208
# Updating variant Blacks - XL - 67 - 902 - 78.png with product id 208
# [967] Updated product[208] - Blacks - XL - 67 - 902
# Updating variant Blacks - S - 55 - 804 - 78.png with product id 208
# Updating variant Blacks - S - 55 - 804 - 78.png with product id 208
# [968] Updated product[208] - Blacks - S - 55 - 804
# Updating variant Blacks - XXL - 70 - 658 - 78.png with product id 208
# Updating variant Blacks - XXL - 70 - 658 - 78.png with product id 208
# [969] Updated product[208] - Blacks - XXL - 70 - 658
# Updating variant Blacks - M - 58 - 895 - 78.png with product id 208
# Updating variant Blacks - M - 58 - 895 - 78.png with product id 208
# [970] Updated product[208] - Blacks - M - 58 - 895
# Updating variant Blacks - XS - 52 - 226 - 78.png with product id 208
# Updating variant Blacks - XS - 52 - 226 - 78.png with product id 208
# [971] Updated product[208] - Blacks - XS - 52 - 226
# Updating variant Browns - S - 55 - 246 - 79.png with product id 208
# Updating variant Browns - S - 55 - 246 - 79.png with product id 208
# [972] Updated product[208] - Browns - S - 55 - 246
# Updating variant Browns - L - 64 - 519 - 79.png with product id 208
# Updating variant Browns - L - 64 - 519 - 79.png with product id 208
# [973] Updated product[208] - Browns - L - 64 - 519
# Updating variant Browns - XL - 67 - 310 - 79.png with product id 208
# Updating variant Browns - XL - 67 - 310 - 79.png with product id 208
# [974] Updated product[208] - Browns - XL - 67 - 310
# Updating variant Browns - XS - 52 - 181 - 79.png with product id 208
# Updating variant Browns - XS - 52 - 181 - 79.png with product id 208
# [975] Updated product[208] - Browns - XS - 52 - 181
# Updating variant Greys - XXL - 70 - 669 - 80.png with product id 208
# Updating variant Greys - XXL - 70 - 669 - 80.png with product id 208
# [976] Updated product[208] - Greys - XXL - 70 - 669
# Updating variant Greys - XL - 67 - 275 - 80.png with product id 208
# Updating variant Greys - XL - 67 - 275 - 80.png with product id 208
# [977] Updated product[208] - Greys - XL - 67 - 275
# Updating variant Greys - S - 55 - 979 - 80.png with product id 208
# Updating variant Greys - S - 55 - 979 - 80.png with product id 208
# [978] Updated product[208] - Greys - S - 55 - 979
# [?] !Chambray Bermuda shorts - "Chambray Bermuda shorts" [92.png]
# ├──Blues - M - 37 - 295 - 92.png
# ├──Blues - S - 35 - 540 - 92.png
# └──Blues - L - 41 - 447 - 92.png
# Added product Chambray Bermuda shorts with id 209
# Updating variant Blues - M - 37 - 295 - 92.png with product id 209
# Updating variant Blues - M - 37 - 295 - 92.png with product id 209
# [979] Updated product[209] - Blues - M - 37 - 295
# Updating variant Blues - S - 35 - 540 - 92.png with product id 209
# Updating variant Blues - S - 35 - 540 - 92.png with product id 209
# [980] Updated product[209] - Blues - S - 35 - 540
# Updating variant Blues - L - 41 - 447 - 92.png with product id 209
# Updating variant Blues - L - 41 - 447 - 92.png with product id 209
# [981] Updated product[209] - Blues - L - 41 - 447
# [?] !Slim-fit seersucker stretch trousers - "Slim-fit seersucker stretch trousers" [94.png]
# └──Browns - XS - 52 - 570 - 94.png
# Added product Slim-fit seersucker stretch trousers with id 210
# Updating variant Browns - XS - 52 - 570 - 94.png with product id 210
# Updating variant Browns - XS - 52 - 570 - 94.png with product id 210
# [982] Updated product[210] - Browns - XS - 52 - 570
# [?] !100% linen bermuda shorts with drawstring - "100% linen bermuda shorts with drawstring" [96.png]
# ├──Blues - XL - 57 - 399 - 96.png
# ├──Blues - XXL - 60 - 811 - 96.png
# ├──Blues - XS - 44 - 148 - 96.png
# ├──Blues - M - 50 - 134 - 96.png
# └──Blues - L - 55 - 457 - 96.png
# Added product 100% linen bermuda shorts with drawstring with id 211
# Updating variant Blues - XL - 57 - 399 - 96.png with product id 211
# Updating variant Blues - XL - 57 - 399 - 96.png with product id 211
# [983] Updated product[211] - Blues - XL - 57 - 399
# Updating variant Blues - XXL - 60 - 811 - 96.png with product id 211
# Updating variant Blues - XXL - 60 - 811 - 96.png with product id 211
# [984] Updated product[211] - Blues - XXL - 60 - 811
# Updating variant Blues - XS - 44 - 148 - 96.png with product id 211
# Updating variant Blues - XS - 44 - 148 - 96.png with product id 211
# [985] Updated product[211] - Blues - XS - 44 - 148
# Updating variant Blues - M - 50 - 134 - 96.png with product id 211
# Updating variant Blues - M - 50 - 134 - 96.png with product id 211
# [986] Updated product[211] - Blues - M - 50 - 134
# Updating variant Blues - L - 55 - 457 - 96.png with product id 211
# Updating variant Blues - L - 55 - 457 - 96.png with product id 211
# [987] Updated product[211] - Blues - L - 55 - 457
# [?] !Slim-fit trousers with drawstring - "Slim-fit trousers with drawstring" [98.png]
# ├──Beiges - XL - 57 - 364 - 98.png
# └──Beiges - XXL - 60 - 251 - 98.png
# Added product Slim-fit trousers with drawstring with id 212
# Updating variant Beiges - XL - 57 - 364 - 98.png with product id 212
# Updating variant Beiges - XL - 57 - 364 - 98.png with product id 212
# [988] Updated product[212] - Beiges - XL - 57 - 364
# Updating variant Beiges - XXL - 60 - 251 - 98.png with product id 212
# Updating variant Beiges - XXL - 60 - 251 - 98.png with product id 212
# [989] Updated product[212] - Beiges - XXL - 60 - 251
# [?] !100% linen bermuda shorts with drawstring - "100% linen bermuda shorts with drawstring" [100.png]
# ├──Reds - XL - 57 - 865 - 100.png
# ├──Reds - XXL - 60 - 108 - 100.png
# ├──Reds - L - 55 - 817 - 100.png
# ├──Reds - M - 50 - 417 - 100.png
# └──Reds - XS - 44 - 970 - 100.png
# Added product 100% linen bermuda shorts with drawstring with id 213
# Updating variant Reds - XL - 57 - 865 - 100.png with product id 213
# Updating variant Reds - XL - 57 - 865 - 100.png with product id 213
# [990] Updated product[213] - Reds - XL - 57 - 865
# Updating variant Reds - XXL - 60 - 108 - 100.png with product id 213
# Updating variant Reds - XXL - 60 - 108 - 100.png with product id 213
# [991] Updated product[213] - Reds - XXL - 60 - 108
# Updating variant Reds - L - 55 - 817 - 100.png with product id 213
# Updating variant Reds - L - 55 - 817 - 100.png with product id 213
# [992] Updated product[213] - Reds - L - 55 - 817
# Updating variant Reds - M - 50 - 417 - 100.png with product id 213
# Updating variant Reds - M - 50 - 417 - 100.png with product id 213
# [993] Updated product[213] - Reds - M - 50 - 417
# Updating variant Reds - XS - 44 - 970 - 100.png with product id 213
# Updating variant Reds - XS - 44 - 970 - 100.png with product id 213
# [994] Updated product[213] - Reds - XS - 44 - 970
# [?] !Slim-fit denim bermuda shorts - "Slim-fit denim bermuda shorts" [103.png]
# ├──Beiges - S - 35 - 854 - 103.png
# ├──Beiges - L - 41 - 216 - 103.png
# ├──Beiges - XL - 43 - 367 - 103.png
# ├──Beiges - XXL - 45 - 317 - 103.png
# ├──Greys - XS - 33 - 893 - 104.png
# ├──Greys - L - 41 - 882 - 104.png
# ├──Greys - XL - 43 - 879 - 104.png
# ├──Greys - M - 37 - 323 - 104.png
# ├──Greys - XXL - 45 - 915 - 104.png
# └──Greys - S - 35 - 448 - 104.png
# Added product Slim-fit denim bermuda shorts with id 214
# Updating variant Beiges - S - 35 - 854 - 103.png with product id 214
# Updating variant Beiges - S - 35 - 854 - 103.png with product id 214
# [995] Updated product[214] - Beiges - S - 35 - 854
# Updating variant Beiges - L - 41 - 216 - 103.png with product id 214
# Updating variant Beiges - L - 41 - 216 - 103.png with product id 214
# [996] Updated product[214] - Beiges - L - 41 - 216
# Updating variant Beiges - XL - 43 - 367 - 103.png with product id 214
# Updating variant Beiges - XL - 43 - 367 - 103.png with product id 214
# [997] Updated product[214] - Beiges - XL - 43 - 367
# Updating variant Beiges - XXL - 45 - 317 - 103.png with product id 214
# Updating variant Beiges - XXL - 45 - 317 - 103.png with product id 214
# [998] Updated product[214] - Beiges - XXL - 45 - 317
# Updating variant Greys - XS - 33 - 893 - 104.png with product id 214
# Updating variant Greys - XS - 33 - 893 - 104.png with product id 214
# [999] Updated product[214] - Greys - XS - 33 - 893
# Updating variant Greys - L - 41 - 882 - 104.png with product id 214
# Updating variant Greys - L - 41 - 882 - 104.png with product id 214
# [1000] Updated product[214] - Greys - L - 41 - 882
# Updating variant Greys - XL - 43 - 879 - 104.png with product id 214
# Updating variant Greys - XL - 43 - 879 - 104.png with product id 214
# [1001] Updated product[214] - Greys - XL - 43 - 879
# Updating variant Greys - M - 37 - 323 - 104.png with product id 214
# Updating variant Greys - M - 37 - 323 - 104.png with product id 214
# [1002] Updated product[214] - Greys - M - 37 - 323
# Updating variant Greys - XXL - 45 - 915 - 104.png with product id 214
# Updating variant Greys - XXL - 45 - 915 - 104.png with product id 214
# [1003] Updated product[214] - Greys - XXL - 45 - 915
# Updating variant Greys - S - 35 - 448 - 104.png with product id 214
# Updating variant Greys - S - 35 - 448 - 104.png with product id 214
# ...
# [1295] Updated product[253] - Browns - XL - 38 - 211
# Updating variant Browns - XXL - 40 - 622 - 308.png with product id 253
# Updating variant Browns - XXL - 40 - 622 - 308.png with product id 253
# [1296] Updated product[253] - Browns - XXL - 40 - 622
# [?] !Patent leather-effect shoes with buckle - "Patent leather-effect shoes with buckle" [310.png]
# ├──Blacks - XL - 57 - 829 - 310.png
# ├──Blacks - S - 47 - 811 - 310.png
# └──Blacks - M - 50 - 540 - 310.png
# Added product Patent leather-effect shoes with buckle with id 254
# Updating variant Blacks - XL - 57 - 829 - 310.png with product id 254
# Updating variant Blacks - XL - 57 - 829 - 310.png with product id 254
# [1297] Updated product[254] - Blacks - XL - 57 - 829
# Updating variant Blacks - S - 47 - 811 - 310.png with product id 254
# Updating variant Blacks - S - 47 - 811 - 310.png with product id 254
# [1298] Updated product[254] - Blacks - S - 47 - 811
# Updating variant Blacks - M - 50 - 540 - 310.png with product id 254
# Updating variant Blacks - M - 50 - 540 - 310.png with product id 254
# [1299] Updated product[254] - Blacks - M - 50 - 540
# [?] !Metallic heel sandals - "Metallic heel sandals" [312.png]
# └──Whites - L - 64 - 398 - 312.png
# Added product Metallic heel sandals with id 255
# Updating variant Whites - L - 64 - 398 - 312.png with product id 255
# Updating variant Whites - L - 64 - 398 - 312.png with product id 255
# [1300] Updated product[255] - Whites - L - 64 - 398
# [?] !Block-heel sandals - "Block-heel sandals" [315.png]
# ├──Beiges - M - 50 - 134 - 315.png
# ├──Beiges - XXL - 60 - 774 - 315.png
# ├──Beiges - XL - 57 - 544 - 315.png
# ├──Beiges - L - 55 - 160 - 315.png
# ├──Beiges - XS - 44 - 656 - 315.png
# └──Beiges - S - 47 - 509 - 315.png
# Added product Block-heel sandals with id 256
# Updating variant Beiges - M - 50 - 134 - 315.png with product id 256
# Updating variant Beiges - M - 50 - 134 - 315.png with product id 256
# [1301] Updated product[256] - Beiges - M - 50 - 134
# Updating variant Beiges - XXL - 60 - 774 - 315.png with product id 256
# Updating variant Beiges - XXL - 60 - 774 - 315.png with product id 256
# [1302] Updated product[256] - Beiges - XXL - 60 - 774
# Updating variant Beiges - XL - 57 - 544 - 315.png with product id 256
# Updating variant Beiges - XL - 57 - 544 - 315.png with product id 256
# [1303] Updated product[256] - Beiges - XL - 57 - 544
# Updating variant Beiges - L - 55 - 160 - 315.png with product id 256
# Updating variant Beiges - L - 55 - 160 - 315.png with product id 256
# [1304] Updated product[256] - Beiges - L - 55 - 160
# Updating variant Beiges - XS - 44 - 656 - 315.png with product id 256
# Updating variant Beiges - XS - 44 - 656 - 315.png with product id 256
# [1305] Updated product[256] - Beiges - XS - 44 - 656
# Updating variant Beiges - S - 47 - 509 - 315.png with product id 256
# Updating variant Beiges - S - 47 - 509 - 315.png with product id 256
# [1306] Updated product[256] - Beiges - S - 47 - 509
# [?] !Platform maxi sandals - "Platform maxi sandals" [317.png]
# ├──Blacks - S - 55 - 455 - 317.png
# └──Blacks - XL - 67 - 270 - 317.png
# Added product Platform maxi sandals with id 257
# Updating variant Blacks - S - 55 - 455 - 317.png with product id 257
# Updating variant Blacks - S - 55 - 455 - 317.png with product id 257
# [1307] Updated product[257] - Blacks - S - 55 - 455
# Updating variant Blacks - XL - 67 - 270 - 317.png with product id 257
# Updating variant Blacks - XL - 67 - 270 - 317.png with product id 257
# [1308] Updated product[257] - Blacks - XL - 67 - 270
# [?] !Block-heel sandals - "Block-heel sandals" [319.png]
# ├──Blacks - XS - 44 - 906 - 319.png
# └──Blacks - L - 55 - 473 - 319.png
# Added product Block-heel sandals with id 258
# Updating variant Blacks - XS - 44 - 906 - 319.png with product id 258
# Updating variant Blacks - XS - 44 - 906 - 319.png with product id 258
# [1309] Updated product[258] - Blacks - XS - 44 - 906
# Updating variant Blacks - L - 55 - 473 - 319.png with product id 258
# Updating variant Blacks - L - 55 - 473 - 319.png with product id 258
# [1310] Updated product[258] - Blacks - L - 55 - 473
# [?] !Satin ballerinas with buckle - "Satin ballerinas with buckle" [322.png]
# ├──Pinks - M - 45 - 240 - 322.png
# └──Pinks - XL - 53 - 435 - 322.png
# Added product Satin ballerinas with buckle with id 259
# Updating variant Pinks - M - 45 - 240 - 322.png with product id 259
# Updating variant Pinks - M - 45 - 240 - 322.png with product id 259
# [1311] Updated product[259] - Pinks - M - 45 - 240
# Updating variant Pinks - XL - 53 - 435 - 322.png with product id 259
# Updating variant Pinks - XL - 53 - 435 - 322.png with product id 259
# [1312] Updated product[259] - Pinks - XL - 53 - 435
# [?] !High-heeled sandals with buckles - "High-heeled sandals with buckles" [324.png]
# ├──Pinks - XS - 44 - 443 - 324.png
# ├──Pinks - S - 47 - 969 - 324.png
# └──Pinks - XXL - 60 - 151 - 324.png
# Added product High-heeled sandals with buckles with id 260
# Updating variant Pinks - XS - 44 - 443 - 324.png with product id 260
# Updating variant Pinks - XS - 44 - 443 - 324.png with product id 260
# [1313] Updated product[260] - Pinks - XS - 44 - 443
# Updating variant Pinks - S - 47 - 969 - 324.png with product id 260
# Updating variant Pinks - S - 47 - 969 - 324.png with product id 260
# [1314] Updated product[260] - Pinks - S - 47 - 969
# Updating variant Pinks - XXL - 60 - 151 - 324.png with product id 260
# Updating variant Pinks - XXL - 60 - 151 - 324.png with product id 260
# [1315] Updated product[260] - Pinks - XXL - 60 - 151
# [?] !Pointed toe heel shoes - "Pointed toe heel shoes" [327.png]
# ├──Beiges - XXL - 50 - 339 - 327.png
# ├──Beiges - L - 46 - 956 - 327.png
# ├──Beiges - M - 41 - 160 - 327.png
# ├──Beiges - XL - 48 - 581 - 327.png
# ├──Beiges - S - 39 - 910 - 327.png
# ├──Beiges - XS - 37 - 228 - 327.png
# ├──Blacks - XXL - 50 - 491 - 328.png
# ├──Blacks - XS - 37 - 153 - 328.png
# ├──Blacks - XL - 48 - 593 - 328.png
# ├──Blacks - S - 39 - 866 - 328.png
# ├──Blacks - L - 46 - 449 - 328.png
# └──Blacks - M - 41 - 640 - 328.png
# Added product Pointed toe heel shoes with id 261
# Updating variant Beiges - XXL - 50 - 339 - 327.png with product id 261
# Updating variant Beiges - XXL - 50 - 339 - 327.png with product id 261
# [1316] Updated product[261] - Beiges - XXL - 50 - 339
# Updating variant Beiges - L - 46 - 956 - 327.png with product id 261
# Updating variant Beiges - L - 46 - 956 - 327.png with product id 261
# [1317] Updated product[261] - Beiges - L - 46 - 956
# Updating variant Beiges - M - 41 - 160 - 327.png with product id 261
# Updating variant Beiges - M - 41 - 160 - 327.png with product id 261
# [1318] Updated product[261] - Beiges - M - 41 - 160
# Updating variant Beiges - XL - 48 - 581 - 327.png with product id 261
# Updating variant Beiges - XL - 48 - 581 - 327.png with product id 261
# [1319] Updated product[261] - Beiges - XL - 48 - 581
# Updating variant Beiges - S - 39 - 910 - 327.png with product id 261
# Updating variant Beiges - S - 39 - 910 - 327.png with product id 261
# [1320] Updated product[261] - Beiges - S - 39 - 910
# Updating variant Beiges - XS - 37 - 228 - 327.png with product id 261
# Updating variant Beiges - XS - 37 - 228 - 327.png with product id 261
# [1321] Updated product[261] - Beiges - XS - 37 - 228
# Updating variant Blacks - XXL - 50 - 491 - 328.png with product id 261
# Updating variant Blacks - XXL - 50 - 491 - 328.png with product id 261
# [1322] Updated product[261] - Blacks - XXL - 50 - 491
# Updating variant Blacks - XS - 37 - 153 - 328.png with product id 261
# Updating variant Blacks - XS - 37 - 153 - 328.png with product id 261
# [1323] Updated product[261] - Blacks - XS - 37 - 153
# Updating variant Blacks - XL - 48 - 593 - 328.png with product id 261
# Updating variant Blacks - XL - 48 - 593 - 328.png with product id 261
# [1324] Updated product[261] - Blacks - XL - 48 - 593
# Updating variant Blacks - S - 39 - 866 - 328.png with product id 261
# Updating variant Blacks - S - 39 - 866 - 328.png with product id 261
# [1325] Updated product[261] - Blacks - S - 39 - 866
# Updating variant Blacks - L - 46 - 449 - 328.png with product id 261
# Updating variant Blacks - L - 46 - 449 - 328.png with product id 261
# [1326] Updated product[261] - Blacks - L - 46 - 449
# Updating variant Blacks - M - 41 - 640 - 328.png with product id 261
# Updating variant Blacks - M - 41 - 640 - 328.png with product id 261
# [1327] Updated product[261] - Blacks - M - 41 - 640
# [?] !Denim ballerinas - "Denim ballerinas" [331.png]
# ├──Blues - M - 41 - 840 - 331.png
# ├──Blues - XS - 37 - 335 - 331.png
# ├──Blues - L - 46 - 538 - 331.png
# ├──Blues - XL - 48 - 603 - 331.png
# ├──Blues - XXL - 50 - 269 - 331.png
# └──Blues - S - 39 - 985 - 331.png
# Added product Denim ballerinas with id 262
# Updating variant Blues - M - 41 - 840 - 331.png with product id 262
# Updating variant Blues - M - 41 - 840 - 331.png with product id 262
# [1328] Updated product[262] - Blues - M - 41 - 840
# Updating variant Blues - XS - 37 - 335 - 331.png with product id 262
# Updating variant Blues - XS - 37 - 335 - 331.png with product id 262
# [1329] Updated product[262] - Blues - XS - 37 - 335
# Updating variant Blues - L - 46 - 538 - 331.png with product id 262
# Updating variant Blues - L - 46 - 538 - 331.png with product id 262
# [1330] Updated product[262] - Blues - L - 46 - 538
# Updating variant Blues - XL - 48 - 603 - 331.png with product id 262
# Updating variant Blues - XL - 48 - 603 - 331.png with product id 262
# [1331] Updated product[262] - Blues - XL - 48 - 603
# Updating variant Blues - XXL - 50 - 269 - 331.png with product id 262
# Updating variant Blues - XXL - 50 - 269 - 331.png with product id 262
# [1332] Updated product[262] - Blues - XXL - 50 - 269
# Updating variant Blues - S - 39 - 985 - 331.png with product id 262
# Updating variant Blues - S - 39 - 985 - 331.png with product id 262
# [1333] Updated product[262] - Blues - S - 39 - 985
# [?] !Asymmetrical heeled shoes - "Asymmetrical heeled shoes" [333.png]
# ├──Beiges - XXL - 50 - 900 - 333.png
# ├──Beiges - XL - 48 - 153 - 333.png
# ├──Beiges - M - 41 - 378 - 333.png
# ├──Beiges - S - 39 - 903 - 333.png
# ├──Beiges - L - 46 - 502 - 333.png
# ├──Beiges - M - 41 - 283 - 334.png
# ├──Beiges - XS - 37 - 584 - 334.png
# ├──Beiges - S - 39 - 197 - 334.png
# ├──Beiges - L - 46 - 195 - 334.png
# ├──Beiges - XL - 48 - 747 - 334.png
# ├──Beiges - XXL - 50 - 933 - 334.png
# ├──Blacks - XXL - 50 - 908 - 335.png
# ├──Blacks - XS - 37 - 148 - 335.png
# ├──Blacks - M - 41 - 708 - 335.png
# ├──Blacks - L - 46 - 787 - 335.png
# ├──Whites - XXL - 50 - 586 - 336.png
# ├──Whites - XL - 48 - 981 - 336.png
# ├──Whites - M - 41 - 404 - 336.png
# ├──Whites - S - 39 - 182 - 336.png
# ├──Pinks - XL - 48 - 840 - 337.png
# ├──Pinks - XXL - 50 - 766 - 337.png
# ├──Pinks - S - 39 - 861 - 337.png
# ├──Pinks - L - 46 - 361 - 337.png
# ├──Pinks - XS - 37 - 115 - 337.png
# ├──Pinks - M - 41 - 765 - 337.png
# ├──Browns - XL - 48 - 803 - 338.png
# └──Browns - L - 46 - 628 - 338.png
# Added product Asymmetrical heeled shoes with id 263
# Updating variant Beiges - XXL - 50 - 900 - 333.png with product id 263
# Updating variant Beiges - XXL - 50 - 900 - 333.png with product id 263
# [1334] Updated product[263] - Beiges - XXL - 50 - 900
# Updating variant Beiges - XL - 48 - 153 - 333.png with product id 263
# Updating variant Beiges - XL - 48 - 153 - 333.png with product id 263
# [1335] Updated product[263] - Beiges - XL - 48 - 153
# Updating variant Beiges - M - 41 - 378 - 333.png with product id 263
# Updating variant Beiges - M - 41 - 378 - 333.png with product id 263
# [1336] Updated product[263] - Beiges - M - 41 - 378
# Updating variant Beiges - S - 39 - 903 - 333.png with product id 263
# Updating variant Beiges - S - 39 - 903 - 333.png with product id 263
# [1337] Updated product[263] - Beiges - S - 39 - 903
# Updating variant Beiges - L - 46 - 502 - 333.png with product id 263
# Updating variant Beiges - L - 46 - 502 - 333.png with product id 263
# [1338] Updated product[263] - Beiges - L - 46 - 502
# Updating variant Beiges - M - 41 - 283 - 334.png with product id 263
# Updating variant Beiges - M - 41 - 283 - 334.png with product id 263
# [1336] Updated product[263] - Beiges - M - 41 - 283
# Updating variant Beiges - XS - 37 - 584 - 334.png with product id 263
# Updating variant Beiges - XS - 37 - 584 - 334.png with product id 263
# [1339] Updated product[263] - Beiges - XS - 37 - 584
# Updating variant Beiges - S - 39 - 197 - 334.png with product id 263
# Updating variant Beiges - S - 39 - 197 - 334.png with product id 263
# [1337] Updated product[263] - Beiges - S - 39 - 197
# Updating variant Beiges - L - 46 - 195 - 334.png with product id 263
# Updating variant Beiges - L - 46 - 195 - 334.png with product id 263
# [1338] Updated product[263] - Beiges - L - 46 - 195
# Updating variant Beiges - XL - 48 - 747 - 334.png with product id 263
# Updating variant Beiges - XL - 48 - 747 - 334.png with product id 263
# [1335] Updated product[263] - Beiges - XL - 48 - 747
# Updating variant Beiges - XXL - 50 - 933 - 334.png with product id 263
# Updating variant Beiges - XXL - 50 - 933 - 334.png with product id 263
# [1334] Updated product[263] - Beiges - XXL - 50 - 933
# Updating variant Blacks - XXL - 50 - 908 - 335.png with product id 263
# Updating variant Blacks - XXL - 50 - 908 - 335.png with product id 263
# [1340] Updated product[263] - Blacks - XXL - 50 - 908
# Updating variant Blacks - XS - 37 - 148 - 335.png with product id 263
# Updating variant Blacks - XS - 37 - 148 - 335.png with product id 263
# [1341] Updated product[263] - Blacks - XS - 37 - 148
# Updating variant Blacks - M - 41 - 708 - 335.png with product id 263
# Updating variant Blacks - M - 41 - 708 - 335.png with product id 263
# [1342] Updated product[263] - Blacks - M - 41 - 708
# Updating variant Blacks - L - 46 - 787 - 335.png with product id 263
# Updating variant Blacks - L - 46 - 787 - 335.png with product id 263
# [1343] Updated product[263] - Blacks - L - 46 - 787
# Updating variant Whites - XXL - 50 - 586 - 336.png with product id 263
# Updating variant Whites - XXL - 50 - 586 - 336.png with product id 263
# [1344] Updated product[263] - Whites - XXL - 50 - 586
# Updating variant Whites - XL - 48 - 981 - 336.png with product id 263
# Updating variant Whites - XL - 48 - 981 - 336.png with product id 263
# [1345] Updated product[263] - Whites - XL - 48 - 981
# Updating variant Whites - M - 41 - 404 - 336.png with product id 263
# Updating variant Whites - M - 41 - 404 - 336.png with product id 263
# [1346] Updated product[263] - Whites - M - 41 - 404
# Updating variant Whites - S - 39 - 182 - 336.png with product id 263
# Updating variant Whites - S - 39 - 182 - 336.png with product id 263
# [1347] Updated product[263] - Whites - S - 39 - 182
# Updating variant Pinks - XL - 48 - 840 - 337.png with product id 263
# Updating variant Pinks - XL - 48 - 840 - 337.png with product id 263
# [1348] Updated product[263] - Pinks - XL - 48 - 840
# Updating variant Pinks - XXL - 50 - 766 - 337.png with product id 263
# Updating variant Pinks - XXL - 50 - 766 - 337.png with product id 263
# [1349] Updated product[263] - Pinks - XXL - 50 - 766
# Updating variant Pinks - S - 39 - 861 - 337.png with product id 263
# Updating variant Pinks - S - 39 - 861 - 337.png with product id 263
# [1350] Updated product[263] - Pinks - S - 39 - 861
# Updating variant Pinks - L - 46 - 361 - 337.png with product id 263
# Updating variant Pinks - L - 46 - 361 - 337.png with product id 263
# [1351] Updated product[263] - Pinks - L - 46 - 361
# Updating variant Pinks - XS - 37 - 115 - 337.png with product id 263
# Updating variant Pinks - XS - 37 - 115 - 337.png with product id 263
# [1352] Updated product[263] - Pinks - XS - 37 - 115
# Updating variant Pinks - M - 41 - 765 - 337.png with product id 263
# Updating variant Pinks - M - 41 - 765 - 337.png with product id 263
# [1353] Updated product[263] - Pinks - M - 41 - 765
# Updating variant Browns - XL - 48 - 803 - 338.png with product id 263
# Updating variant Browns - XL - 48 - 803 - 338.png with product id 263
# [1354] Updated product[263] - Browns - XL - 48 - 803
# Updating variant Browns - L - 46 - 628 - 338.png with product id 263
# Updating variant Browns - L - 46 - 628 - 338.png with product id 263
# [1355] Updated product[263] - Browns - L - 46 - 628

# %%
len(Products)
# Out:
# 76

# %%
product_dataframe[product_dataframe['id'] % 2 == 1]
a = product_dataframe[product_dataframe['id'] % 2 == 1].values.tolist()
a
# Out:
# []

# %%
Products = []
